# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
o_ai = np.array([0.05, 0.10])
t_ak = np.array([0.01, 0.99])
u = np.array([0.35, 0.60])  #threshold or bias

# %%
w_ij = np.array([[0.15, 0.25],[0.20, 0.30]])

# %%
w_ij
# Out:
# array([[0.15, 0.25],
#        [0.2 , 0.3 ]])

# %%
w_jk = np.array([[0.40, 0.50],[0.45, 0.55]])

# %%
w_jk
# Out:
# array([[0.4 , 0.5 ],
#        [0.45, 0.55]])

# %%
n1=1
k1=1
n2=1
k2=1
# Out:
# 0.2907576303928937

# %%
# w_jk[1][0]

# %%
def summation(W,X):
    result = []
    for i in range(len(X)):
        SUM = 0
        for j in range(W.shape[0]):
            SUM += W[j][i]*X[j]
            
        result.append(SUM)
        
        
    return result

# %%
def SUM(del_a,w):
#     print(w.shape[0])
    result = []
    for i in range(len(del_a)):
        SUM = 0
        for j in range(w.shape[0]):
            SUM += del_a[j]*w[i][j]
            
        result.append(SUM)
        
        
    return result

# %%
def sigmoid(x):
    return 1 / (1 + np.exp(-k1*x))

# %%
Min_Error = 0.001

while(True):
    # EQUATION 1
    net_aj = summation(w_ij, o_ai)
    
    # EQUATION 2
    u_hj = u[0]
    activ_j = net_aj + u_hj
    
    # EQUATION 3
    o_aj = sigmoid(activ_j)
    
    # EQUATION 4
    net_ak = summation(w_jk, o_aj)
    
    # EQUATION 5
    u_ok = u[1]
    activo_k = net_ak + u_ok
    
    # EQUATION 6
    o_ak = sigmoid(activo_k)
    
    # EQUATION 7
    del_ak = t_ak - o_ak
    
    # EQUATION 8
    del_w_jk = n2*k2*del_ak*o_aj*o_ak*(1-o_ak)
    
    # EQUATION 9
    w_jk = w_jk + del_w_jk
    
    # EQUATION 10
    del_u_ok = n2*k2*del_ak*o_ak*(1-o_ak)
    
    # EQUATION 11
    u_ok = u_ok + del_u_ok
    
    # EQUATION 12
    del_w_ij = n2*k2*o_ai*o_aj*(1-o_aj)*SUM(del_ak,w_jk)
    
    # EQUATION 13
    w_ij = w_ij + del_w_ij
    
    # EQUATION 14
    del_u_hj = n1*k1*o_aj*(1-o_aj)*SUM(del_ak,w_jk)
    
    # EQUATION 15
    u_hj = u_hj + del_u_hj
    
    # EQUATION 16
    Error = 0.5*sum((t_ak-o_ak)*(t_ak-o_ak))
    print(Error)
    
    if(Error <= Min_Error):
        break
# Out:
# 0.2983711087600027
# 0.2836545113747834
# 0.2684442707050492
# 0.25287022678156595
# 0.23709641716632676
# 0.2213134561430947
# 0.2057264884289774
# 0.19054009326459653
# 0.17594250388959912
# 0.16209188570781513
# 0.14910696016352573
# 0.13706312595161735
# 0.12599387718571078
# 0.1158962546465324
# 0.10673858013004695
# 0.09846880447868728
# 0.09102223480409258
# 0.0843279438018403
# 0.07831362550889655
# 0.0729089721571955
# 0.06804780799624183
# 0.06366926679404747
# 0.059718284794992055
# 0.05614563564682926
# 0.05290768085852349
# 0.049965960627511366
# 0.04728671012284694
# 0.044840356248378475
# 0.04260102838912106
# 0.040546101906172756
# 0.03865578345242824
# 0.03691274106889894
# 0.03530177835870773
# 0.033809549996030974
# 0.03242431482923452
# 0.031135722484903414
# 0.029934629409109757
# 0.028812940523430697
# 0.027763473018142207
# 0.026779839187701576
# 0.02585634559538869
# 0.024987906213503955
# 0.024169967512413324
# 0.023398443762165357
# 0.022669661064422014
# 0.021980308852173357
# 0.021327397783303653
# 0.020708223115069424
# 0.020120332783456735
# 0.019561499527515014
# 0.01902969649711059
# 0.001275286678098913
# 0.0012697833174990824
# 0.0012643171988400202
# 0.0012588879713286189
# 0.001253495288431721
# 0.0012481388078126841
# 0.0012428181912690476
# 0.001237533104671244
# 0.0012322832179024817
# 0.0012270682047995961
# 0.001221887743094998
# 0.0012167415143595557
# 0.0012116292039465763
# 0.0012065505009366492
# 0.001201505098083515
# 0.001196492691760823
# 0.0011915129819098428
# 0.0011865656719880404
# 0.0011816504689185568
# 0.001176767083040498
# 0.0011719152280601501
# 0.0011670946210029457
# 0.0011623049821662848
# 0.0011575460350731438
# 0.0011528175064264476
# 0.0011481191260642263
# 0.0011434506269155063
# 0.0011388117449569585
# 0.0011342022191702375
# 0.0011296217915000425
# 0.0011250702068128981
# 0.0011205472128565624
# 0.0011160525602201424
# 0.001111586002294857
# 0.0011071472952354322
# 0.0011027361979221314
# 0.001098352471923407
# 0.0010939958814591682
# 0.0010896661933645906
# 0.0010853631770546299
# 0.0010810866044889448
# 0.001076836250137513
# 0.0010726118909467684
# 0.0010684133063062194
# 0.001064240278015691
# 0.0010600925902530176
# 0.0010559700295422795
# 0.0010518723847225443
# 0.0010477994469170922
# 0.0010437510095031152
# 0.0010397268680819246
# 0.0010357268204495998
# 0.0010317506665681033
# 0.0010277982085368366
# 0.0010238692505646569
# 0.0010199635989423382
# 0.0010160810620153864
# 0.0010122214501573873
# 0.0010083845757436745
# 0.0010045702531254232
# 0.0010007782986041736
# 0.0009970085304067127

# %%
w_ij
# Out:
# array([[1.38111348, 2.62977738],
#        [1.43111348, 2.67977738]])

# %%
w_jk
# Out:
# array([[-2.85669394,  1.91450248],
#        [-2.80669394,  1.96450248]])

# %%
# # EQUATION 1
# net_aj = summation(w_ij, o_ai)

# %%
# net_aj

# %%
# # EQUATION 2
# u_hj = u[0]
# activ_j = net_aj + u_hj

# %%
# # EQUATION 3
# o_aj = sigmoid(activ_j)

# %%
# o_aj

# %%
# # EQUATION 4
# net_ak = summation(w_jk, o_aj)

# %%
# # EQUATION 5
# u_ok = u[1]
# activo_k = net_ak + u_ok

# %%
# # EQUATION 6
# o_ak = sigmoid(activo_k)

# %%
# o_ak

# %%
# # EQUATION 7
# del_ak = t_ak - o_ak

# %%
# del_ak

# %%
# # EQUATION 8
# n2=1
# k2=1
# del_w_jk = n2*k2*del_ak*o_aj*o_ak*(1-o_ak)

# %%
# # EQUATION 9
# w_jk = w_jk + del_w_jk

# %%
# w_jk

# %%
# # EQUATION 10
# del_u_ok = n2*k2*del_ak*o_ak*(1-o_ak)

# %%
# del_u_ok

# %%
# # EQUATION 11
# u_ok = u_ok + del_u_ok

# %%
# u_ok

# %%
# del_ak

# %%
# w_jk

# %%
# result = SUM(del_ak,w_jk)

# %%
# result

# %%
# # EQUATION 12
# n1=1
# k1=1
# del_w_ij = n2*k2*o_ai*o_aj*(1-o_aj)*SUM(del_ak,w_jk)

# %%
# del_w_ij

# %%
# # EQUATION 13
# w_ij = w_ij + del_w_ij

# %%
# # EQUATION 14
# n1=1
# k1=1
# del_u_hj = n1*k1*o_aj*(1-o_aj)*SUM(del_ak,w_jk)

# %%
# # EQUATION 15
# u_hj = u_hj + del_u_hj

# %%
# t_ak

# %%
# o_ak

# %%
# sum((t_ak-o_ak)*(t_ak-o_ak))

# %%
# # EQUATION 16
# Error = 0.5*sum((t_ak-o_ak)*(t_ak-o_ak))

# %%
# Error
